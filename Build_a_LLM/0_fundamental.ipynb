# %%
import numpy as np

# %%
a = np.array([2, 1])

# %%
print(a)
# Out:
# [2 1]

# %%
type(a)
# Out:
# numpy.ndarray

# %%
d = np.array([[1], [5]])

# %%
print(d)
# Out:
# [[1]
#  [5]]

# %%
type(d)
# Out:
# numpy.ndarray

# %%
print(d.T)
# Out:
# [[1 5]]

# %%
print(d.T.T)
# Out:
# [[1]
#  [5]]

# %%
a = np.array([1, 2])
b = np.array([2, 5])

# %%
a + b
# Out:
# array([3, 7])
